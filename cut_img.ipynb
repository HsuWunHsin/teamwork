# %%
import cv2
import numpy as np
import os
import glob
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
# list np.array
# 讀取資料
images = [cv2.imread(file) for file in glob.glob("data/*.jpg")]
images
# Out:
# [array([[[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         ...,
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [254, 254, 254],
#          [253, 255, 255],
#          [253, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [254, 254, 254],
#          [255, 255, 255],
#          [253, 255, 255]],
#
#         [[255, 255, 255],
# ...

# %%
m2 = []
m3 = []
for b in images:
    m2 = b[17: 17 + 529, 24:24 + 915]
    plt.imshow(m2)
    plt.show()
    m3.append(m2)
# Out:
# [array([[[252, 252, 252],
#         [251, 253, 253],
#         [254, 254, 254],
#         ...,
#         [255, 254, 253],
#         [255, 255, 251],
#         [255, 254, 250]],
#
#        [[255, 255, 254],
#         [255, 255, 254],
#         [255, 254, 253],
#         ...,
#         [254, 255, 251],
#         [255, 255, 249],
#         [254, 254, 248]],
#
#        [[254, 255, 253],
#         [254, 255, 253],
#         [255, 254, 253],
#         ...,
#         [252, 255, 251],
#         [253, 254, 250],
#         [254, 254, 248]],
#
#        ...,
#
#        [[155, 159, 187],
#         [212, 214, 238],
#         [249, 249, 255],
#         ...,
#         [226, 233, 252],
#         [243, 250, 255],
#         [241, 245, 246]],
#
#        [[155, 158, 186],
#         [237, 238, 255],
#         [252, 251, 255],
#         ...,
#         [248, 251, 255],
#         [250, 253, 255],
#         [253, 255, 255]],
#
#        [[218, 221, 242],
#         [246, 248, 255],
#         [245, 246, 250],
# ...

# %%
for i, g in enumerate (m3):
    cv2.imwrite("output/" + str(i) + ".jpg", g)
